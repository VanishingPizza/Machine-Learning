# %% [markdown]
# <a href="https://colab.research.google.com/github/VanishingPizza/Machine-Learning/blob/main/HW1/HW1_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Analysis

# %% [markdown]
# ### Question 1: Based on the instructional videos, what are the key steps for managing files between Google Colab and GitHub?

# %% [markdown]
# Answer: The key steps for managing giles between Google Colab and GitHub are to select your preferred repository and/or branch and then enter the file path for where one would like to copy the notebook in the GitHub repository, this includes the name of the folder in the GitHub repository that you would like the notebook to be copied to as well. Finally, it is key to ensure the "Include a link to Colab" checkbox is selected, which helps to open a notebook from GitHub using a "Open in Colab" link.

# %% [markdown]
# ### Question 2: Did all Module 0 notebooks execute successfully in Colab on the first try, or did you need to adjust any syntax or dependencies?

# %% [markdown]
# Answer: Yes, all Module 0 notebooks were executed successfully in Colab on the first try with 0s latency. There was no need for any adjustments to syntax or dependencies.

# %% [markdown]
# ### Question 3: Explain how you created your repository and organized your files (whether using VS Code or the GitHub web interface).

# %% [markdown]
# I created my repository using the GitHub web interface and created my folders by first making README files. I then added the notebooks after running each of them to the HW1 folder then synced the changes made on the Github web interface to my VS Code. This was done by going to source control and enabling the repository to be shown. Once the repository was shown I was able to synchronize changes by clicking on an icon and all the files on GitHub were cloned to my local VS Code.

# %% [markdown]
# ### Question 4: Why is establishing a strong command of basic Python data structures and syntax critical before moving on to core machine learning algorithms?

# %% [markdown]
# Answer: It is critical to establish a strong command of basic Python data structures and syntax early on because we will be dealing with datasets and will be manipulating alot of data, so it is important to grasp the understanding of data structures which may be heavily involved in ML algorithms. Dictionaries, for example, are a primary structure used to manipulate hyperparameters, dataset configurations and training options in Machine Learning pipelines.
